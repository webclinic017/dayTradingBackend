# %%
import django_intializer
from historicalTesting.views import *
# Out:
# /Users/shashwatyadav/.pyenv/versions/3.7.7/envs/daytrade/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = HistoricalAnalysis.update_indicator(136432388,['sma'])

# %%
df_strategy_1 = HistoricalAnalysis.define_position(df,1)
df_strategy_2 = HistoricalAnalysis.define_position(df,2)
df_strategy_3 = HistoricalAnalysis.define_position(df,3)
df_strategy_4 = HistoricalAnalysis.define_position(df,4)
df_strategy_5 = HistoricalAnalysis.define_position(df,5)
# Out:
# /Users/shashwatyadav/Projects/DayTradingAutomation/dayTradeBackend/historicalTesting/views.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['position'][row] = position
# /Users/shashwatyadav/Projects/DayTradingAutomation/dayTradeBackend/historicalTesting/views.py:563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['position'][row] = position
# /Users/shashwatyadav/Projects/DayTradingAutomation/dayTradeBackend/historicalTesting/views.py:589: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_return_1 = HistoricalAnalysis.calculate_returns(df_strategy_1,num_units=100)
df_return_2 = HistoricalAnalysis.calculate_returns(df_strategy_2,num_units=100)
df_return_3 = HistoricalAnalysis.calculate_returns(df_strategy_3,num_units=100)
df_return_4 = HistoricalAnalysis.calculate_returns(df_strategy_4,num_units=100)
df_return_5 = HistoricalAnalysis.calculate_returns(df_strategy_5,num_units=100)
# Out:
# /Users/shashwatyadav/Projects/DayTradingAutomation/dayTradeBackend/historicalTesting/views.py:463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['trade_return'][row] = calculated_return
# /Users/shashwatyadav/Projects/DayTradingAutomation/dayTradeBackend/historicalTesting/views.py:471: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['hwm'][row] = hwm
# /Users/shashwatyadav/Projects/DayTradingAutomation/dayTradeBackend/historicalTesting/views.py:472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
daily_summary_1 = df_return_1['daily_summary']
daily_summary_2 = df_return_2['daily_summary']
daily_summary_3 = df_return_3['daily_summary']
daily_summary_4 = df_return_4['daily_summary']
daily_summary_5 = df_return_5['daily_summary']

output_data_1 = df_return_1['output_data']
output_data_2 = df_return_2['output_data']
output_data_3 = df_return_3['output_data']
output_data_4 = df_return_4['output_data']
output_data_5 = df_return_5['output_data']

# %%
comparative_summary = daily_summary_1
comparative_summary = comparative_summary.append(daily_summary_2)
comparative_summary = comparative_summary.append(daily_summary_3)
comparative_summary = comparative_summary.append(daily_summary_4)
comparative_summary = comparative_summary.append(daily_summary_5)
comparative_summary
# Out:
#   instrument_token            strategy        date  day_return  max_drawdown  \
# 0        136432388  1: SMA 20 on 5 > 1  2021-12-31    1.004956      0.002616
# 0        136432388  2: SMA 15 on 5 > 1  2021-12-31    1.013287      0.003774
# 0        136432388  3: SMA 30 on 5 > 1  2021-12-31    1.014738      0.001882
# 0        136432388  4: SMA 10 on 5 > 1  2021-12-31    1.026804      0.002667
# 0        136432388  5: SMA 10 on 3 > 1  2021-12-31    1.034160      0.003446
#
#    high_water_mark  total_sales  total_purchases
# 0         1.006445            7                7
# 0         1.017061            9                9
# 0         1.014738            5                5
# 0         1.027949           18               18
# 0         1.036862           25               25

# %%
plot_indicator = plot_indicators(output_data_1,['close_price','sma_3','sma_10'],'sma_ratio_10on3',1)
plot_indicator.show()

# %%
plot_return = plot_returns(output_data_5,['cumulative_return','hwm'],'drawdown')
plot_return.show()

# %%
output_data_5
# Out:
#     instrument_token                  datetime   tradedate  open_price  \
# 0          136432388 2021-12-31 09:15:00+00:00  2021-12-31       13.40
# 1          136432388 2021-12-31 09:16:00+00:00  2021-12-31       12.90
# 2          136432388 2021-12-31 09:17:00+00:00  2021-12-31       13.26
# 3          136432388 2021-12-31 09:18:00+00:00  2021-12-31       13.26
# 4          136432388 2021-12-31 09:19:00+00:00  2021-12-31       13.20
# ..               ...                       ...         ...         ...
# 370        136432388 2021-12-31 15:25:00+00:00  2021-12-31       13.63
# 371        136432388 2021-12-31 15:26:00+00:00  2021-12-31       13.67
# 372        136432388 2021-12-31 15:27:00+00:00  2021-12-31       13.67
# 373        136432388 2021-12-31 15:28:00+00:00  2021-12-31       13.67
# 374        136432388 2021-12-31 15:29:00+00:00  2021-12-31       13.67
#
#      close_price  high_price  low_price   volume      sma_2      sma_3  ...  \
# ...
